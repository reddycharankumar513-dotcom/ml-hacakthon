# %% [markdown]
# # 03 Feature Engineering & Importance Analysis
# Inspect feature distributions, feature importances, and correlation matrices for pair feature vectors.

# %%
import sys
import os
import pandas as pd
sys.path.insert(0, '../src')
from business_entity_resolution.config import load_config

config = load_config('../config.yaml')
imp_path = os.path.join('../', config['artifacts']['reports_dir'], 'feature_importance.csv')
if os.path.exists(imp_path):
    df_imp = pd.read_csv(imp_path)
    print(df_imp.head(20))
