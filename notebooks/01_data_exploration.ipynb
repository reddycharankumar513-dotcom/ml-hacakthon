# %% [markdown]
# # 01 Data Exploration & Quality Analysis
# Inspect row counts, missingness, country distribution, and noise patterns across Source 1, 2, and 3.

# %%
import sys
import pandas as pd
sys.path.insert(0, '../src')
from business_entity_resolution.config import load_config
from business_entity_resolution.io import load_all_datasets
from business_entity_resolution.profiling import profile_single_dataframe

config = load_config('../config.yaml')
datasets, df_gt = load_all_datasets(config, sample_size=10000)
print({k: len(v) for k, v in datasets.items()})
