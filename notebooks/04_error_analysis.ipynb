# %% [markdown]
# # 04 Error Analysis & Failure Mode Breakdown
# Analyze false positives, false negatives, singleton misclassifications, and number conflicts.

# %%
import sys
import os
import pandas as pd
sys.path.insert(0, '../src')
from business_entity_resolution.config import load_config

config = load_config('../config.yaml')
err_path = os.path.join('../', config['artifacts']['reports_dir'], 'error_analysis.csv')
if os.path.exists(err_path):
    df_err = pd.read_csv(err_path)
    print(df_err['error_type'].value_counts())
    print(df_err.head(10))
